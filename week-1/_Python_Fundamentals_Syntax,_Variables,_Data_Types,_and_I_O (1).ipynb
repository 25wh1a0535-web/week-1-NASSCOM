# %%
print('HELLO,python!')
# Out:
# HELLO,python!

# %%
if True:
  print("this is indended correctly.")
else:
  print("this won't run")
# Out:
# this is indended correctly.

# %%
name = "Ayesha"
age = 18
section = "CSE-A"

print("NAME : ",name)
print("AGE :" , age)
print("SECTION :" , section)
# Out:
# NAME :  Ayesha
# AGE : 18
# SECTION : CSE-A

# %%
a = 10
print(type(a))
# Out:
# <class 'int'>

# %%
b = "Ayesha"
print(type(b))
# Out:
# <class 'str'>

# %%
c = 22.3
print(type(c))
# Out:
# <class 'float'>

# %%
c = "Python"
print(type(c))

# Boolean
d = True
print(type(d))

# List
e = [1, 2, 3, "four"]
print(type(e), e)

# Dictionary
f = {"name": "Alice", "age": 25}
print(type(f), f)
# Out:
# <class 'str'>
# <class 'bool'>
# <class 'list'> [1, 2, 3, 'four']
# <class 'dict'> {'name': 'Alice', 'age': 25}

# %%
print("Welcome Ayesha!")
# Out:
# Welcome Ayesha!

# %%
user_name = input("Enter your name: ")
print("Hello,", user_name)
# Out:
# Enter your name: ayesha
# Hello, ayesha

# %%
user_age = int(input("Enter your age: "))
print("You will be", user_age + 1, "next year.")
# Out:
# Enter your age: 18
# You will be 19 next year.
