# %%
fruits = ['apple', 'banana', 'cherry', 'apple']
print("Original list:", fruits)

print("First fruit:", fruits[0])
# Out:
# Original list: ['apple', 'banana', 'cherry', 'apple']
# First fruit: apple

# %%
fruits.append('orange')
print("After appending:" ,fruits)
# Out:
# After appending: ['apple', 'banana', 'cherry', 'apple', 'orange']

# %%
fruits.remove('banana')
print("After removing:" ,fruits)
# Out:
# After removing: ['apple', 'cherry', 'apple', 'orange']

# %%
print("number of fruits:" ,len(fruits))
# Out:
# number of fruits: 4

# %%
dimensions=(10,20,30)
print("Tuple :" ,dimensions)
# Out:
# Tuple : (10, 20, 30)

# %%
print("Second element :" ,dimensions[1])
# Out:
# Second element : 20

# %%
unique_numbers = {1, 2, 3,3,4, 2, 1}
print("Set (no duplicates):", unique_numbers)
# Out:
# Set (no duplicates): {1, 2, 3, 4}

# %%
unique_numbers.add(5)
print("After adding :" ,unique_numbers)
# Out:
# After adding : {1, 2, 3, 4, 5}

# %%
unique_numbers.remove(3)
print("After removing :" ,unique_numbers)
# Out:
# After removing : {1, 2, 4, 5}

# %%
set_a = {1,2,3,4}
set_b = {4,5,6,7}
print("Union :" ,set_a | set_b)
print("Intersection :" ,set_a & set_b)
print("Difference (A-B) :" ,set_a - set_b)
# Out:
# Union : {1, 2, 3, 4, 5, 6, 7}
# Intersection : {4}
# Difference (A-B) : {1, 2, 3}

# %%
student = {
    'name': 'Ayesha',
    'age': 18,
    'course': 'Python'
}
print("Dictionary:", student)
# Out:
# Dictionary: {'name': 'Ayesha', 'age': 18, 'course': 'Python'}

# %%
print("Student name :" ,student['name'])
# Out:
# Student name : Ayesha

# %%
student['grade'] = 'A'
print("After adding grade:", student)


del student['age']
print("After deleting age:", student)

for key, value in student.items():
    print(f"{key}: {value}")
# Out:
# After adding grade: {'name': 'Ayesha', 'age': 18, 'course': 'Python', 'grade': 'A'}
# After deleting age: {'name': 'Ayesha', 'course': 'Python', 'grade': 'A'}
# name: Ayesha
# course: Python
# grade: A

# %%
keys = ['id', 'name', 'marks']
values = [101, 'John', 88]
student_info = dict(zip(keys, values))
print("Student Info from zip:", student_info)
# Out:
# Student Info from zip: {'id': 101, 'name': 'John', 'marks': 88}
